# %%
import matplotlib.pyplot as plt
import numpy as np
import mplcursors
# %matplotlib widget

data = np.outer(range(10), range(1, 5))

fig, ax = plt.subplots()
lines = ax.plot(data)
ax.set_title("Click somewhere on a line.\nRight-click to deselect.\n"
             "Annotations can be dragged.")

mplcursors.cursor(lines)  # or just mplcursors.cursor()

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Out:
# Requirement already satisfied: jupyterlab in /home/nathan/anaconda3/lib/python3.7/site-packages (3.2.1)
# Collecting jupyterlab
#   Downloading jupyterlab-3.4.4-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 4.9 MB/s eta 0:00:01
# Collecting ipympl
#   Downloading ipympl-0.9.1-py2.py3-none-any.whl (508 kB)
#      |████████████████████████████████| 508 kB 4.9 MB/s eta 0:00:01
# Requirement already satisfied: nbclassic in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab) (0.2.6)
# Collecting jupyterlab-server~=2.10
#   Downloading jupyterlab_server-2.15.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: tornado>=6.1.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab) (6.1)
# Requirement already satisfied: packaging in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab) (21.0)
# Collecting jupyter-server~=1.16
#   Downloading jupyter_server-1.18.1-py3-none-any.whl (344 kB)
#      |████████████████████████████████| 344 kB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: jinja2>=2.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab) (2.11.3)
# Requirement already satisfied: ipython in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab) (7.29.0)
# Requirement already satisfied: notebook<7 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab) (6.4.6)
# Requirement already satisfied: jupyter-core in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab) (4.9.1)
# Requirement already satisfied: pillow in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipympl) (8.4.0)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: ipython-genutils in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipympl) (3.4.3)
# Requirement already satisfied: numpy in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipympl) (1.21.5)
# Requirement already satisfied: traitlets<6 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipympl) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (3.0.20)
# Requirement already satisfied: matplotlib-inline in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (0.1.2)
# Requirement already satisfied: decorator in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (5.1.0)
# Requirement already satisfied: pickleshare in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (58.0.4)
# Requirement already satisfied: pygments in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (2.10.0)
# Requirement already satisfied: backcall in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipywidgets<8,>=7.6.0->ipympl) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipywidgets<8,>=7.6.0->ipympl) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipywidgets<8,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipywidgets<8,>=7.6.0->ipympl) (3.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (6.1.12)
# Requirement already satisfied: importlib-metadata<5 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (4.8.1)
# Requirement already satisfied: argcomplete>=1.12.3 in /home/nathan/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (1.12.3)
# Requirement already satisfied: zipp>=0.5 in /home/nathan/anaconda3/lib/python3.7/site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/nathan/anaconda3/lib/python3.7/site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (3.10.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jedi>=0.16->ipython->jupyterlab) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jinja2>=2.1->jupyterlab) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (22.3.0)
# Requirement already satisfied: prometheus-client in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyter-server~=1.16->jupyterlab) (0.11.0)
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.4.0-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: terminado>=0.8.3 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyter-server~=1.16->jupyterlab) (0.9.4)
# Requirement already satisfied: argon2-cffi in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyter-server~=1.16->jupyterlab) (20.1.0)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 4.2 MB/s eta 0:00:01
# Collecting websocket-client
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: Send2Trash in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyter-server~=1.16->jupyterlab) (1.8.0)
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-6.5.0-py3-none-any.whl (561 kB)
#      |████████████████████████████████| 561 kB 3.7 MB/s eta 0:00:01
# Requirement already satisfied: idna>=2.8 in /home/nathan/anaconda3/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab) (3.2)
# Requirement already satisfied: sniffio>=1.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab) (1.2.0)
# Collecting jinja2>=2.1
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 3.3 MB/s eta 0:00:01
# Requirement already satisfied: jsonschema>=3.0.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab-server~=2.10->jupyterlab) (3.2.0)
# Requirement already satisfied: requests in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.26.0)
# Requirement already satisfied: babel in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.9.1)
# Requirement already satisfied: json5 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jupyterlab-server~=2.10->jupyterlab) (0.9.6)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: six>=1.11.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (0.18.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/nathan/anaconda3/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.1.2)
# Requirement already satisfied: defusedxml in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (4.10.0)
# Collecting tinycss2
#   Downloading tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.8.4)
# Requirement already satisfied: bleach in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (4.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.3)
# Requirement already satisfied: async-generator in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbclient>=0.5.0->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (1.10)
# Requirement already satisfied: nest-asyncio in /home/nathan/anaconda3/lib/python3.7/site-packages (from nbclient>=0.5.0->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (1.5.1)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.1-py3-none-any.whl (22 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/nathan/anaconda3/lib/python3.7/site-packages (from pexpect>4.3->ipython->jupyterlab) (0.7.0)
# Requirement already satisfied: wcwidth in /home/nathan/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab) (1.15.0)
# Requirement already satisfied: pycparser in /home/nathan/anaconda3/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.16->jupyterlab) (2.20)
# Requirement already satisfied: pytz>=2015.7 in /home/nathan/anaconda3/lib/python3.7/site-packages (from babel->jupyterlab-server~=2.10->jupyterlab) (2021.1)
# Requirement already satisfied: soupsieve>1.2 in /home/nathan/anaconda3/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (2.2.1)
# Requirement already satisfied: webencodings in /home/nathan/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.5.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/nathan/anaconda3/lib/python3.7/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/nathan/anaconda3/lib/python3.7/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nathan/anaconda3/lib/python3.7/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (2021.10.8)
# Installing collected packages: fastjsonschema, nbformat, MarkupSafe, tinycss2, jinja2, nbconvert, websocket-client, anyio, jupyter-server, jupyterlab-server, jupyterlab, ipympl
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.1.3
#     Uninstalling nbformat-5.1.3:
#       Successfully uninstalled nbformat-5.1.3
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.3.0
#     Uninstalling nbconvert-6.3.0:
#       Successfully uninstalled nbconvert-6.3.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 2.2.0
#     Uninstalling anyio-2.2.0:
#       Successfully uninstalled anyio-2.2.0
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.4.1
#     Uninstalling jupyter-server-1.4.1:
#       Successfully uninstalled jupyter-server-1.4.1
#   Attempting uninstall: jupyterlab-server
#     Found existing installation: jupyterlab-server 2.8.2
#     Uninstalling jupyterlab-server-2.8.2:
#       Successfully uninstalled jupyterlab-server-2.8.2
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 3.2.1
#     Uninstalling jupyterlab-3.2.1:
#       Successfully uninstalled jupyterlab-3.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# cookiecutter 1.7.2 requires Jinja2<3.0.0, but you have jinja2 3.1.2 which is incompatible.
# cookiecutter 1.7.2 requires MarkupSafe<2.0.0, but you have markupsafe 2.1.1 which is incompatible.
# Successfully installed MarkupSafe-2.1.1 anyio-3.6.1 fastjsonschema-2.16.1 ipympl-0.9.1 jinja2-3.1.2 jupyter-server-1.18.1 jupyterlab-3.4.4 jupyterlab-server-2.15.0 nbconvert-6.5.0 nbformat-5.4.0 tinycss2-1.1.1 websocket-client-1.3.3
# Note: you may need to restart the kernel to use updated packages.
